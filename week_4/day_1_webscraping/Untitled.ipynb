# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
page = requests.get('https://www.the-numbers.com/box-office-star-records/domestic/lifetime-specific-technical-role/director')
print(page)
page.content
web_content = BeautifulSoup(page.content, 'html.parser')
web_content
print(web_content.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html>
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1343128-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1343128-1');
#   </script>
#   <meta content='(PICS-1.1 "https://www.icra.org/ratingsv02.html" l gen true for "https://www.the-numbers.com/" r (cb 1 lz 1 nz 1 oz 1 vz 1) "https://www.rsac.org/ratingsv01.html" l gen true for "https://www.the-numbers.com/" r (n 0 s 0 v 0 l 0))' http-equiv="PICS-Label"/>
#   <!--<meta http-equiv="Content-Type" content="text/html; charset=ISO-8859-1" >-->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <!-- for apple mobile -->
#   <meta content="521546213" property="fb:admins">
# ...

# %%
web_content.find_all('td', class_='data', align='right' )
web_content.find_all('td', align='right')
info = web_content.find_all('td', align='right')
info
# Out:
# [<td align="right">$4,542,164,603</td>,
#  <td align="right">36</td>,
#  <td align="right">$126,171,239</td>,
#  <td align="right">$2,326,279,619</td>,
#  <td align="right">15</td>,
#  <td align="right">$155,085,308</td>,
#  <td align="right">$2,280,821,799</td>,
#  <td align="right">6</td>,
#  <td align="right">$380,136,967</td>,
#  <td align="right">$2,280,821,799</td>,
#  <td align="right">6</td>,
#  <td align="right">$380,136,967</td>,
#  <td align="right">$2,186,095,188</td>,
#  <td align="right">6</td>,
#  <td align="right">$364,349,198</td>,
#  <td align="right">$2,152,298,031</td>,
#  <td align="right">13</td>,
#  <td align="right">$165,561,387</td>,
#  <td align="right">$2,105,111,762</td>,
#  <td align="right">30</td>,
#  <td align="right">$70,170,392</td>,
#  <td align="right">$2,103,136,169</td>,
#  <td align="right">21</td>,
#  <td align="right">$100,149,341</td>,
#  <td align="right">$2,003,864,469</td>,
#  <td align="right">12</td>,
# ...

# %%
directors = web_content.select('b a')
directors = [i.get_text() for i in directors]  # get_text() retrieves information inside the tags
directors = directors[:100]
directors
# Out:
# ['Steven Spielberg',
#  'Michael Bay',
#  'Joe Russo',
#  'Anthony Russo',
#  'J.J. Abrams',
#  'Peter Jackson',
#  'Ron Howard',
#  'Robert Zemeckis',
#  'Christopher Nolan',
#  'Clint Eastwood',
#  'James Cameron',
#  'Tim Burton',
#  'Jon Favreau',
#  'David Yates',
#  'Chris Columbus',
#  'George Lucas',
#  'Ridley Scott',
#  'Sam Raimi',
#  'Gore Verbinski',
#  'Francis Lawrence',
#  'Brad Bird',
#  'Todd Phillips',
#  'Chris Renaud',
#  'Bryan Singer',
#  'Roland Emmerich',
#  'M. Night Shyamalan',
#  'Zack Snyder',
#  'Bill Condon',
#  'Pierre Coffin',
#  'Andrew Stanton',
#  'Andrew Adamson',
#  'Brett Ratner',
#  'Shawn Levy',
#  'Jay Roach',
#  'James Wan',
#  'Joss Whedon',
#  'Ivan Reitman',
#  'Dennis Dugan',
#  'Tony Scott',
#  'Richard Donner',
#  'Barry Sonnenfeld',
#  'Steven Soderbergh',
#  'Jon Turteltaub',
#  'John Lasseter',
#  'Conrad Vernon',
#  'Martin Scorsese',
#  'Garry Marshall',
#  'Tyler Perry',
#  'Joel Schumacher',
#  'Pete Docter',
#  'Sam Mendes',
# ...

# %%
info[0].text
# Out:
# '$4,542,164,603'

# %%
info2 = [td.text for td in info]
info2
# Out:
# ['$4,542,164,603',
#  '36',
#  '$126,171,239',
#  '$2,326,279,619',
#  '15',
#  '$155,085,308',
#  '$2,280,821,799',
#  '6',
#  '$380,136,967',
#  '$2,280,821,799',
#  '6',
#  '$380,136,967',
#  '$2,186,095,188',
#  '6',
#  '$364,349,198',
#  '$2,152,298,031',
#  '13',
#  '$165,561,387',
#  '$2,105,111,762',
#  '30',
#  '$70,170,392',
#  '$2,103,136,169',
#  '21',
#  '$100,149,341',
#  '$2,003,864,469',
#  '12',
#  '$166,988,706',
#  '$1,980,838,946',
#  '37',
#  '$53,536,188',
#  '$1,973,102,841',
#  '14',
#  '$140,935,917',
#  '$1,952,305,730',
#  '19',
#  '$102,752,933',
#  '$1,878,450,274',
#  '9',
#  '$208,716,697',
#  '$1,791,787,800',
#  '8',
#  '$223,973,475',
#  '$1,750,209,687',
#  '16',
#  '$109,388,105',
#  '$1,741,495,001',
#  '6',
#  '$290,249,167',
#  '$1,660,578,335',
#  '28',
#  '$59,306,369',
#  '$1,529,444,211',
#  '14',
#  '$109,246,015',
#  '$1,529,313,769',
#  '11',
#  '$139,028,524',
#  '$1,481,481,244',
#  '9',
#  '$164,609,027',
#  '$1,402,462,020',
#  '6',
# ...

# %%
table1 = []
for number in list(range(0,len(info2))):
    if number%3 == 0:
        table1.append(info2[number])

# %%
table1 = [x[1:] for x in table1]

# %%
table1 = [x.replace(',', '') for x in table1]

# %%
table1 = [int(x) for x in table1]

# %%
dbo = table1

# %%
info2 = [td.text for td in info]
movie_count = []
for number in list(range(0,len(info2))):
    if number%3 == 1:
        movie_count.append(info2[number])

# %%
movie_count = [int(x) for x in movie_count]

# %%
avg_bo = []
for number in list(range(0,len(info2))):
    if number%3 == 2:
        avg_bo.append(info2[number])

# %%
avg_bo = [x[1:] for x in avg_bo]

# %%
avg_bo = [x.replace(',', '') for x in avg_bo]

# %%
avg_bo = [int(x) for x in avg_bo]

# %%
#directors, dbo, movie_count, avg_bo

# %%
df = pd.DataFrame([directors, dbo, movie_count, avg_bo]).T
df.columns = ['Director', 'Domestic Box Office', 'Number of Movies', 'AVG Box Office']
df.shape
# Out:
# (100, 4)

# %%
for i in list(range(0,10)):
    if i == 0: 
        url = 'https://www.the-numbers.com/box-office-star-records/domestic/lifetime-specific-technical-role/director'
    else: 
        url = 'https://www.the-numbers.com/box-office-star-records/domestic/lifetime-specific-technical-role/director/{}01'.format(i)
    html_page = request.get(url)
    web_content = BeautifulSoup(html_page.content, 'html.parser')

# %%
def retrieve_directors(soup):
