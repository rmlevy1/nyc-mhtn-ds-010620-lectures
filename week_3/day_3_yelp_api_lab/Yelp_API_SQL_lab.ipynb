# %% [markdown]
# # Yelp API - Lab
#
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, it's time to put those API and SQL skills to work in order to do some basic business analysis! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create a DB on AWS to store information from Yelp about businesses
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and insert the information into your DB
# * Perform pagination to retrieve troves of data!
# * Write SQL queries to answer questions about your data

# %% [markdown]
# ## Problem Introduction
#
# For this lab you will analyze the yelp data for a group of businesses to learn more about an industry. You will choose a type of business (Italian Restuarants, Nail Salons, Crossfit gyms) and a location to analyze. Then you will get data from the Yelp API, store that data in a SQL Database on AWS, and write queries to answer questions about the data.
#
#
# ### Process:
#
# 1. Read through the SQL questions and the API documentation to determine which pieces of information you need to pull from the Yelp API.
#
# 2. Create a DB schema with 2 tables. One for the businesses and one for the reviews.
#
# 3. Create code to:
#   - Perform a search of businesses using pagination
#   - Parse the API response for specific data points
#   - Insert the data into your AWS DB
#
# 4. Use the functions above in a loop that will paginate over the results to retrieve all of the results.
#
# 5. Create functions to:
#   - Retrieve the reviews data of one business
#   - Parse the reviews response for specific review data
#   - Insert the review data into the DB
#
# 6. Using SQL, query all of the business IDs. Using the 3 Python functions you've created, run your business IDs through a loop to get the reviews for each business and insert them into your DB.
#
# 7. Write SQL queries to answer the following questions about your data.
#
#
# Bonus Steps:
# - Place your helper functions in a package so that your final notebook only has the major steps listed.
# - Rewrite your business search functions to be able take an argument for the type of business you are searching for.
# - Add another group of businesses to your database.

# %% [markdown]
#
# ## SQL Questions:
#
# - Which are the 5 most reviewed businesses?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs?
# - Return the text of the reviews for the most reviewed restaurant.
# - Return the name of the business with the most recent review.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the restaurant with the least reviews.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# Look at the question and determine what data you will need to store in your database in order to answer the questions. Start to thin about your DB schema. What tables will you want to create and what columns will you ahve for those tables.
#
# Look at the API documentation, and determine what fields of the API response you will match up with the columns you want in your DB tables.
#
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ## Part 2 - Set up the DB
#
# Now that you are familiar with the data, create your SQL queries to create the DB and the appropriate tables.

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (8.0.19)
# Requirement already satisfied: protobuf==3.6.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from mysql-connector-python) (3.6.1)
# Requirement already satisfied: dnspython==1.16.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from mysql-connector-python) (1.16.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from protobuf==3.6.1->mysql-connector-python) (41.2.0)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from protobuf==3.6.1->mysql-connector-python) (1.12.0)

# %%
import requests
import json

# %%
client_id = 'UJ3sgzXTZYWFuWK3PG9-Qw'
api_key = '6bStfv8q6DhKbrjmsGYuadW142rYO82aNOJIKBftA9q3ITEu_eCtvjUm-N6UmafgY_mP-SD-cOaw__llL6pt4Bp3QCGMkvy8aeUg--SYE1WIfTB_gk4TkPaHKvcpXnYx'

# %%
import requests
term = 'Hotel'
location = 'Manhattan NY'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text)
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "jq9WOcjuFe595Rf8I87Y0Q", "alias": "casablanca-hotel-new-york-2", "name": "Casablanca Hotel", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/XWFa88YzofbKVztqbT0dUA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/casablanca-hotel-new-york-2?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw", "review_count": 84, "categories": [{"alias": "hotels", "title": "Hotels"}], "rating": 4.5, "coordinates": {"latitude": 40.75641, "longitude": -73.98547}, "transactions": [], "price": "$$", "location": {"address1": "147 W 43rd St", "address2": "", "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["147 W 43rd St", "New York, NY 10036"]}, "phone": "+12128691212", "display_phone": "(212) 869-1212", "distance": 716.4452640700139}, {"id": "rK-vxWHue22BCkvd1-X_PQ", "alias": "envue-autograph-collection-weehawken", "name": "Envue, Autograph Collection", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/YiaWf_h0bWVy-QIJj6q1Zw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/envue-autograph-collection-weehawken?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw", "review_count": 15, "categories": [{"alias": "hotels", "title": "Hotels"}, {"alias": "venues", "title": "Venues & Event Spaces"}], "rating": 4.0, "coordinates": {"latitude": 40.77727, "longitude": -74.011165}, "transactions": [], "location": {"address1": "550 Avenue at Port Imperial", "address2": "", "address3": null, "city": "Weehawken", "zip_code": "07086", "country": "US", "state": "NJ", "display_address": ["550 Avenue at Port Imperial", "Weehawken, NJ 07086"]}, "phone": "+12017587920", "display_phone": "(201) 758-7920", "distance": 3341.167386231335}, {"id": "EL5j67uhlTWSFcrsEX9l_Q", "alias": "the-frederick-hotel-new-york", "name": "The Frederick Hotel", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/M9MMwr2beg_0UhfirKL3eg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-frederick-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw", "review_count": 54, "categories": [{"alias": "hotels", "title": "Hotels"}], "rating": 4.0, "coordinates": {"latitude": 40.71566, "longitude": -74.0089}, "transactions": [], "price": "$", "location": {"address1": "95 W Broadway", "address2": "", "address3": null, "city": "New York", "zip_code": "10007", "country": "US", "state": "NY", "display_address": ["95 W Broadway", "New York, NY 10007"]}, "phone": "+12125661900", "display_phone": "(212) 566-1900", "distance": 5584.191768559387}, {"id": "m2eKA1AJTc47YpErc-ikhA", "alias": "courtyard-new-york-manhattan-midtown-east-new-york-6", "name": "Courtyard by Marriott New York Manhattan/Midtown East", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/QOgkits7Kx-t6Ge5a6mgUA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/courtyard-new-york-manhattan-midtown-east-new-york-6?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw", "review_count": 153, "categories": [{"alias": "hotels", "title": "Hotels"}, {"alias": "venues", "title": "Venues & Event Spaces"}], "rating": 4.0, "coordinates": {"latitude": 40.7574547612934, "longitude": -73.9699241362457}, "transactions": [], "price": "$$", "location": {"address1": "866 3rd Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10022", "country": "US", "state": "NY", "display_address": ["866 3rd Ave", "New York, NY 10022"]}, "phone": "+12126441300", "display_phone": "(212) 644-1300", "distance": 784.8406690803926}, {"id": "gJftQIQJUk3F47yq8e0-mg", "alias": "le-m\u00e9ridien-new-york-central-park-new-york", "name": "Le M\u00e9ridien New York, Central Park", "image_url": "http ...

# %%
type(response.json())
# Out:
# dict

# %%
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
response.json()
# Out:
# {'businesses': [{'id': 'jq9WOcjuFe595Rf8I87Y0Q',
#    'alias': 'casablanca-hotel-new-york-2',
#    'name': 'Casablanca Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XWFa88YzofbKVztqbT0dUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casablanca-hotel-new-york-2?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 84,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75641, 'longitude': -73.98547},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '147 W 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12128691212',
#    'display_phone': '(212) 869-1212',
#    'distance': 716.4452640700139},
#   {'id': 'rK-vxWHue22BCkvd1-X_PQ',
#    'alias': 'envue-autograph-collection-weehawken',
#    'name': 'Envue, Autograph Collection',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YiaWf_h0bWVy-QIJj6q1Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/envue-autograph-collection-weehawken?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 15,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77727, 'longitude': -74.011165},
#    'transactions': [],
#    'location': {'address1': '550 Avenue at Port Imperial',
#     'address2': '',
#     'address3': None,
#     'city': 'Weehawken',
#     'zip_code': '07086',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['550 Avenue at Port Imperial', 'Weehawken, NJ 07086']},
#    'phone': '+12017587920',
#    'display_phone': '(201) 758-7920',
#    'distance': 3341.167386231335},
#   {'id': 'EL5j67uhlTWSFcrsEX9l_Q',
#    'alias': 'the-frederick-hotel-new-york',
#    'name': 'The Frederick Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M9MMwr2beg_0UhfirKL3eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-frederick-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 54,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71566, 'longitude': -74.0089},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '95 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 W Broadway', 'New York, NY 10007']},
#    'phone': '+12125661900',
#    'display_phone': '(212) 566-1900',
#    'distance': 5584.191768559387},
#   {'id': 'm2eKA1AJTc47YpErc-ikhA',
#    'alias': 'courtyard-new-york-manhattan-midtown-east-new-york-6',
#    'name': 'Courtyard by Marriott New York Manhattan/Midtown East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QOgkits7Kx-t6Ge5a6mgUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-new-york-manhattan-midtown-east-new-york-6?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 153,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7574547612934,
#     'longitude': -73.9699241362457},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '866 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['866 3rd Ave', 'New York, NY 10022']},
#    'phone': '+12126441300',
#    'display_phone': '(212) 644-1300',
#    'distance': 784.8406690803926},
#   {'id': 'gJftQIQJUk3F47yq8e0-mg',
#    'alias': 'le-méridien-new-york-central-park-new-york',
#    'name': 'Le Méridien New York, Central Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kTkQYbGM16-6Z4aidAeFCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-m%C3%A9ridien-new-york-central-park-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 15,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.764567, 'longitude': -73.978488},
#    'transactions': [],
#    'location': {'address1': '120 West 57th Street',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 West 57th Street', 'New York, NY 10019']},
#    'phone': '+12128308000',
#    'display_phone': '(212) 830-8000',
#    'distance': 479.1841658412056},
#   {'id': 'htWCcFI5R5Cuwod5PNSpow',
#    'alias': '1-hotel-central-park-new-york',
#    'name': '1 Hotel Central Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hWyFWROAi_ogTGNmEBR6iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1-hotel-central-park-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 121,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76471, 'longitude': -73.97651},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1414 Ave Of The Americas',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1414 Ave Of The Americas', 'New York, NY 10019']},
#    'phone': '+12127032001',
#    'display_phone': '(212) 703-2001',
#    'distance': 530.4393085514417},
#   {'id': 'SoSQhqqOaS10aUuxDr1YtA',
#    'alias': 'citizenm-new-york-times-square-hotel-new-york',
#    'name': 'citizenM New York Times Square Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TXMJq94BiZAguBri8L8a-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizenm-new-york-times-square-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 188,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.761561, 'longitude': -73.984968},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '218 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 W 50th St', 'New York, NY 10019']},
#    'phone': '+12124613638',
#    'display_phone': '(212) 461-3638',
#    'distance': 564.9165790299872},
#   {'id': 'zuMUWAduEq4COEcbnZ3XCA',
#    'alias': 'the-park-hyatt-new-york-new-york-city',
#    'name': 'The Park Hyatt New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7j_m_Gu5s8UASB-Eoo1Bqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-park-hyatt-new-york-new-york-city?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 142,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76538, 'longitude': -73.97895},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '153 West 57th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York City',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 West 57th St', 'New York City, NY 10019']},
#    'phone': '+16467741234',
#    'display_phone': '(646) 774-1234',
#    'distance': 592.3907370775254},
#   {'id': 'I9nxS9nBfPgoqpvhsyZTwg',
#    'alias': 'park-terrace-hotel-new-york',
#    'name': 'Park Terrace Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jm_vgLqOK0eXBBmb5Zakbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-terrace-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75249, 'longitude': -73.9831},
#    'transactions': [],
#    'location': {'address1': '18 W 40th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 W 40th St', 'New York, NY 10018']},
#    'phone': '+12127816400',
#    'display_phone': '(212) 781-6400',
#    'distance': 942.1704224485549},
#   {'id': 'GYO8lvStXGZAfFDRlOxQ1Q',
#    'alias': 'hotel-50-bowery-nyc-new-york',
#    'name': 'Hotel 50 Bowery NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VtFY918-5qR0-o-749-e0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-50-bowery-nyc-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 149,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71599, 'longitude': -73.99683},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '50 Bowery',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Bowery', 'New York, NY 10013']},
#    'phone': '+12125088000',
#    'display_phone': '(212) 508-8000',
#    'distance': 5154.994626340236},
#   {'id': 'qwAUa1tcAJMrn2K7Ynbp8w',
#    'alias': 'courtyard-by-marriott-new-york-manhattan-midtown-west-new-york',
#    'name': 'Courtyard by Marriott New York Manhattan/Midtown West',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HfD_xdQF5ImryGAs2ce43w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-by-marriott-new-york-manhattan-midtown-west-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754698, 'longitude': -73.99865},
#    'transactions': [],
#    'location': {'address1': '461 West 34th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['461 West 34th St', 'New York, NY 10001']},
#    'phone': '+12125533000',
#    'display_phone': '(212) 553-3000',
#    'distance': 1804.6262219820126},
#   {'id': 'cUXl19vPkfd9vdqc0OT7_g',
#    'alias': 'the-ludlow-new-york-city-new-york',
#    'name': 'The Ludlow New York City',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HAorlQpwKwmnCvzyxzomnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ludlow-new-york-city-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 132,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721839, 'longitude': -73.987355},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '180 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12124321818',
#    'display_phone': '(212) 432-1818',
#    'distance': 4331.918068180734},
#   {'id': 'JLoLYfqWvcOPIUfxu48qbQ',
#    'alias': 'fairfield-inn-and-suites-new-york-midtown-manhattan-penn-station-new-york-2',
#    'name': 'Fairfield Inn & Suites by Marriott New York',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nn9KCtEct9Lj2Z4K-kyQcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairfield-inn-and-suites-new-york-midtown-manhattan-penn-station-new-york-2?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 107,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7521723402439,
#     'longitude': -73.9951658490235},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '325 W 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 W 33rd St', 'New York, NY 10001']},
#    'phone': '+12125630900',
#    'display_phone': '(212) 563-0900',
#    'distance': 1664.391856132874},
#   {'id': '1Qe4hdNvZQTvNWF3Lwy8vg',
#    'alias': 'fairfield-inn-and-suites-marriott-new-york',
#    'name': 'Fairfield Inn & Suites - Marriott',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NIqppRBOiZKR-UCV6gFI6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairfield-inn-and-suites-marriott-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 59,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.770105527613,
#     'longitude': -73.9892103854588},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '538 W 58th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['538 W 58th St', 'New York, NY 10019']},
#    'phone': '+12127578550',
#    'display_phone': '(212) 757-8550',
#    'distance': 1422.3538438733883},
#   {'id': '0tYMltweY813Iicd8NKATA',
#    'alias': 'the-bernic-hotel-new-york-city-tapestry-collection-by-hilton-new-york',
#    'name': 'The Bernic Hotel New York City, Tapestry Collection by Hilton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ksyzjf0eeLo7BMSI2FojVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bernic-hotel-new-york-city-tapestry-collection-by-hilton-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 73,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75433, 'longitude': -73.97277},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '145 E 47th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 E 47th St', 'New York, NY 10017']},
#    'phone': '+12127549700',
#    'display_phone': '(212) 754-9700',
#    'distance': 810.9530908049022},
#   {'id': 'SUw25KXBf_o61UE8zg1A-Q',
#    'alias': 'the-french-quarters-nyc-new-york',
#    'name': 'The French Quarters NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/euOyLhyqSMKevCRpF-NjXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-french-quarters-nyc-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 74,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7603187561035,
#     'longitude': -73.9897842407227},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '346 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['346 W 46th St', 'New York, NY 10036']},
#    'phone': '+12123596652',
#    'display_phone': '(212) 359-6652',
#    'distance': 950.2974511687347},
#   {'id': 'BnqsLvT7IaPZIibgj35t_Q',
#    'alias': 'the-harlem-flop-house-new-york',
#    'name': 'The Harlem Flop House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HE9IXJMbqA7DryY-jOpg2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harlem-flop-house-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 13,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.80815, 'longitude': -73.9509999},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '242 West 123rd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 West 123rd', 'New York, NY 10027']},
#    'phone': '+12126620678',
#    'display_phone': '(212) 662-0678',
#    'distance': 5816.853224860252},
#   {'id': 'oaxaN-kZuIeZmz7mndoXwA',
#    'alias': 'the-william-new-york',
#    'name': 'The William',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aAVMkexsDbrqhFAFN-DpmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-william-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 42,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.750477, 'longitude': -73.980263},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '24 E 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 E 39th St', 'New York, NY 10016']},
#    'phone': '+16469228600',
#    'display_phone': '(646) 922-8600',
#    'distance': 1092.302031155526},
#   {'id': 'XBZI0dnAxY07fFIHT6_xog',
#    'alias': 'aka-central-park-new-york-2',
#    'name': 'AKA Central Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vnwXi7AkKTuDzsce95XtMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aka-central-park-new-york-2?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 23,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'apartments', 'title': 'Apartments'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7650501395815,
#     'longitude': -73.9767040259338},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '42 W 58th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 W 58th St', 'New York, NY 10019']},
#    'phone': '+16467443100',
#    'display_phone': '(646) 744-3100',
#    'distance': 558.5326313788405},
#   {'id': 'hU6R1o3h9xmhB-2vFNq-JQ',
#    'alias': 'the-nomad-hotel-new-york',
#    'name': 'The NoMad Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ovwkERpse8jGmkoEAyHNBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nomad-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 136,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7451273597477,
#     'longitude': -73.9888644218445},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1170 Broadway & 28th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1170 Broadway & 28th St', 'New York, NY 10001']},
#    'phone': '+12127961500',
#    'display_phone': '(212) 796-1500',
#    'distance': 1891.2089864834888},
#   {'id': 'OxjMJ0ij4QpPEbB8HkEnng',
#    'alias': 'equinox-hotel-new-york',
#    'name': 'Equinox Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JcAZ8tEbrJ_i2ZXlJDlMZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/equinox-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 17,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7547675038206,
#     'longitude': -74.0019863667953},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '33 Hudson Yards',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Hudson Yards', 'New York, NY 10001']},
#    'phone': '+12128129200',
#    'display_phone': '(212) 812-9200',
#    'distance': 2068.8338810094174},
#   {'id': 'T8hRtRz3Q50VC8DX9NRfDg',
#    'alias': 'the-st-regis-new-york-new-york',
#    'name': 'The St. Regis New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ExT6hk0d3j44KO-rogWfog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-st-regis-new-york-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 211,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76136, 'longitude': -73.97443},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Two E 55th St',
#     'address2': 'at Fifth Ave',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Two E 55th St',
#      'at Fifth Ave',
#      'New York, NY 10022']},
#    'phone': '+12127534500',
#    'display_phone': '(212) 753-4500',
#    'distance': 367.88128396140695},
#   {'id': 'sQ7IXiSHR4c5WufgUywizA',
#    'alias': 'hotel-beacon-new-york',
#    'name': 'Hotel Beacon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nknVDPvI3OO7fBrUzyJl3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-beacon-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 111,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.780685, 'longitude': -73.981041},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2130 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2130 Broadway', 'New York, NY 10023']},
#    'phone': '+12127871100',
#    'display_phone': '(212) 787-1100',
#    'distance': 2286.200647483344},
#   {'id': 'cJkIaS5lz7wdraZvGX6QPQ',
#    'alias': 'crowne-plaza-hy36-midtown-manhattan-new-york',
#    'name': 'Crowne Plaza HY36 Midtown Manhattan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3zmC98Ran45d7F7VqIb-Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crowne-plaza-hy36-midtown-manhattan-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 66,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75374, 'longitude': -73.99374},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '320 W 36th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 W 36th St', 'New York, NY 10018']},
#    'phone': '+16469283800',
#    'display_phone': '(646) 928-3800',
#    'distance': 1470.7813974685253},
#   {'id': 'NVsI5DRm1CszltskWJvvZQ',
#    'alias': 'hotel-giraffe-new-york',
#    'name': 'Hotel Giraffe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BdNLCxZSH642yNUqfcZSXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-giraffe-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 193,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74215, 'longitude': -73.98472},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '365 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['365 Park Ave S', 'New York, NY 10016']},
#    'phone': '+12126857700',
#    'display_phone': '(212) 685-7700',
#    'distance': 2080.5991154607027},
#   {'id': '36BEu1qOdQhJNhCQxE-Mcg',
#    'alias': 'the-whitby-hotel-new-york',
#    'name': 'The Whitby Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lMkVgQPRSnehCpn-5mS0bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-whitby-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76271, 'longitude': -73.97566},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '18 W 56th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 W 56th St', 'New York, NY 10019']},
#    'phone': '+12125865656',
#    'display_phone': '(212) 586-5656',
#    'distance': 351.9545054670699},
#   {'id': 'KgIHkPNwzBm8SbQbn8jfFg',
#    'alias': 'terrazzo-bryant-park-new-york-2',
#    'name': 'Terrazzo Bryant Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IkFISycTqgETncBgfM3T0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terrazzo-bryant-park-new-york-2?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 22,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75249, 'longitude': -73.9831},
#    'transactions': [],
#    'location': {'address1': '18 W 40th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 W 40th St', 'New York, NY 10018']},
#    'phone': '+12127816400',
#    'display_phone': '(212) 781-6400',
#    'distance': 942.1704224485549},
#   {'id': 'fEqSedl1uUUfpmfs3mMiwQ',
#    'alias': 'hilton-garden-inn-times-square-new-york',
#    'name': 'Hilton Garden Inn Times Square',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PnVUGB0c1aK7Z6zTU1jAfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-times-square-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 313,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7612053955474,
#     'longitude': -73.9865067601204},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '790 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['790 8th Ave', 'New York, NY 10019']},
#    'phone': '+12125817000',
#    'display_phone': '(212) 581-7000',
#    'distance': 683.2632976174909},
#   {'id': 'qZewWn4-pdd4JfoJSBV1QA',
#    'alias': 'library-hotel-by-library-hotel-collection-new-york',
#    'name': 'Library Hotel by Library Hotel Collection',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HFLHEuFY7CInQPl4PufR7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/library-hotel-by-library-hotel-collection-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 137,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75218, 'longitude': -73.97954},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '299 Madison Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['299 Madison Ave', 'New York, NY 10017']},
#    'phone': '+12129834500',
#    'display_phone': '(212) 983-4500',
#    'distance': 898.7200239417383},
#   {'id': 'mf3_8Spuw_1aspkrqimryw',
#    'alias': 'the-lucerne-hotel-new-york',
#    'name': 'The Lucerne Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AKM3aPslGJ5f9FFU2XNzeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lucerne-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 133,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78337, 'longitude': -73.97847},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '201 W 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 W 79th St', 'New York, NY 10024']},
#    'phone': '+12128751000',
#    'display_phone': '(212) 875-1000',
#    'distance': 2581.0303718482833},
#   {'id': 'qLV7zNf9CE6C1Nsb3i20PQ',
#    'alias': 'cambria-hotel-new-york-chelsea-new-york',
#    'name': 'Cambria Hotel New York - Chelsea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yOxUf7ZWlDgkqTdGMAhEeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambria-hotel-new-york-chelsea-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 99,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746727, 'longitude': -73.991567},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '123 W 28th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 W 28th St', 'New York, NY 10001']},
#    'phone': '+12122444477',
#    'display_phone': '(212) 244-4477',
#    'distance': 1863.0307403736806},
#   {'id': 'fA7iFSxoIQXcCcxSwL5oHw',
#    'alias': 'mandarin-oriental-new-york-new-york-5',
#    'name': 'Mandarin Oriental - New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cIvk-mGbZs4D3t9nGRczGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mandarin-oriental-new-york-new-york-5?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 170,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76847, 'longitude': -73.98309},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '80 Columbus Cir',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Columbus Cir', 'New York, NY 10023']},
#    'phone': '+12128058800',
#    'display_phone': '(212) 805-8800',
#    'distance': 1054.4961588720776},
#   {'id': 'nnAkMNV9Zh6G9BZLLOhfog',
#    'alias': 'baccarat-hotel-new-york-3',
#    'name': 'Baccarat Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MZy7rmF0IJIxFLikOdVmvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baccarat-hotel-new-york-3?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 239,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76091, 'longitude': -73.97732},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '28 W 53rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 W 53rd St', 'New York, NY 10019']},
#    'phone': '+18669575139',
#    'display_phone': '(866) 957-5139',
#    'distance': 121.67893380519943},
#   {'id': '3hbrhvj2D_Zj5s-dPhAA6A',
#    'alias': 'the-lowell-new-york',
#    'name': 'The Lowell',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c0npbltyS1WBnZG5cvXAIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lowell-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 39,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7657388, 'longitude': -73.9692216},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '28 E 63rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 E 63rd St', 'New York, NY 10065']},
#    'phone': '+12128381400',
#    'display_phone': '(212) 838-1400',
#    'distance': 993.9638696010222},
#   {'id': 'ZDp1ysOVW3xQJc4SuQGSCg',
#    'alias': 'archer-hotel-new-york-new-york',
#    'name': 'Archer Hotel New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k9yW6CNlT9UBsHms1-enQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/archer-hotel-new-york-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 183,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7519652, 'longitude': -73.984799},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '45 W 38th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 W 38th St', 'New York, NY 10018']},
#    'phone': '+12127194100',
#    'display_phone': '(212) 719-4100',
#    'distance': 1059.6926417647528},
#   {'id': 'QxobzmaLiP_Tx6cnmpWQPg',
#    'alias': 'arlo-nomad-new-york',
#    'name': 'Arlo NoMad',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/631xqxLYK8OgVoYP_H9xEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arlo-nomad-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 202,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746212, 'longitude': -73.9850458},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11 E 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 E 31st St', 'New York, NY 10016']},
#    'phone': '+12128067000',
#    'display_phone': '(212) 806-7000',
#    'distance': 1651.782851995433},
#   {'id': 'SZTBP6Xj7ER4d3NSbgOA-A',
#    'alias': 'four-seasons-hotel-new-york-4',
#    'name': 'Four Seasons Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9aFIPCHXvZnn6Iu7bMVtDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-seasons-hotel-new-york-4?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 49,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71256, 'longitude': -74.00907},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '27 Barclay St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Barclay St', 'New York, NY 10007']},
#    'phone': '+16468801999',
#    'display_phone': '(646) 880-1999',
#    'distance': 5876.744680718807},
#   {'id': 'QFBUAXg1bZDpi9WUSheGGg',
#    'alias': 'the-lombardy-new-york-3',
#    'name': 'The Lombardy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b1lvHR_JTbQxArHIlun9jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lombardy-new-york-3?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 46,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7607674, 'longitude': -73.9705315},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '111 E 56th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 E 56th St', 'New York, NY 10022']},
#    'phone': '+12127538600',
#    'display_phone': '(212) 753-8600',
#    'distance': 673.975508217515},
#   {'id': '0xp3lHJWVIH-dSxg-uMCUg',
#    'alias': 'crosby-street-hotel-new-york',
#    'name': 'Crosby Street Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uw-02H9o7q_RYEsIlaL0cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crosby-street-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 137,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72299, 'longitude': -73.99739},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '79 Crosby St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Crosby St', 'New York, NY 10012']},
#    'phone': '+12122266400',
#    'display_phone': '(212) 226-6400',
#    'distance': 4428.05491882477},
#   {'id': 'tpxMTuzDG42JuXK5phmxMQ',
#    'alias': 'the-langham-new-york-fifth-avenue-new-york',
#    'name': 'The Langham, New York, Fifth Avenue',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Rat2rTLUnSuVZxSTR_LCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-langham-new-york-fifth-avenue-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 106,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7501, 'longitude': -73.98381},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '400 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['400 5th Ave', 'New York, NY 10018']},
#    'phone': '+12126954005',
#    'display_phone': '(212) 695-4005',
#    'distance': 1212.1243387087184},
#   {'id': 'G_MjJTdblaZeFyvT1T7dnQ',
#    'alias': 'bristol-plaza-new-york-2',
#    'name': 'Bristol Plaza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bBt80se5QySot_KhYN6dWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bristol-plaza-new-york-2?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7650045, 'longitude': -73.9634683},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '210 E 65th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 E 65th St', 'New York, NY 10065']},
#    'phone': '+12128269000',
#    'display_phone': '(212) 826-9000',
#    'distance': 1365.956637304992},
#   {'id': 'NSWg2X5nuqUwi4n5CWYFlA',
#    'alias': 'hotel-hendricks-new-york',
#    'name': 'Hotel Hendricks',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PoiJ-HPX7gS59iarhAP5Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-hendricks-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 21,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.751761, 'longitude': -73.984092},
#    'transactions': [],
#    'location': {'address1': '25 W 38th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 W 38th St', 'New York, NY 10018']},
#    'phone': '+18334363745',
#    'display_phone': '(833) 436-3745',
#    'distance': 1045.050173945416},
#   {'id': 'vgCV1vNhlbUvj9O1baFNHw',
#    'alias': 'the-times-square-edition-new-york',
#    'name': 'The Times Square EDITION',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JWbba_zsng6Ar3EeDP1oWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-times-square-edition-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 56,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7592, 'longitude': -73.9846},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '20 Times Square, 701 7th Avenue at West 47th Street',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Times Square, 701 7th Avenue at West 47th Street',
#      'New York, NY 10036']},
#    'phone': '+12123987017',
#    'display_phone': '(212) 398-7017',
#    'distance': 507.17495460425135},
#   {'id': '29qq6ZOCfxXb7TZ7W5UslQ',
#    'alias': 'kimpton-ink48-hotel-new-york',
#    'name': 'Kimpton Ink48 Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i-bxqqq1b4EDmVOv6iHi-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimpton-ink48-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 492,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'wedding_planning', 'title': 'Wedding Planning'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76452, 'longitude': -73.99586},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '653 11th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['653 11th Ave', 'New York, NY 10036']},
#    'phone': '+12127570088',
#    'display_phone': '(212) 757-0088',
#    'distance': 1547.5675710387673},
#   {'id': '5U3Kk45q34GBCGcL828ZCw',
#    'alias': 'loews-regency-new-york-hotel-new-york-3',
#    'name': 'Loews Regency New York Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RE_clPbO9OM-BLljo-9bIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loews-regency-new-york-hotel-new-york-3?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 84,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764573, 'longitude': -73.968998},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '540 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['540 Park Ave', 'New York, NY 10065']},
#    'phone': '+12127594100',
#    'display_phone': '(212) 759-4100',
#    'distance': 935.5860155014153},
#   {'id': 'm-8qqfAKP5Hw2JZVCx5wQA',
#    'alias': 'lex-hotel-nyc-new-york',
#    'name': 'Lex Hotel NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NjwX-qbH8iFEWxt3L0kAdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lex-hotel-nyc-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 54,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740934, 'longitude': -73.9833419},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '67 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 Lexington Ave', 'New York, NY 10010']},
#    'phone': '+18774540395',
#    'display_phone': '(877) 454-0395',
#    'distance': 2182.3828527439364},
#   {'id': 'Lh-BWBcgFfHi6-zxFhqShg',
#    'alias': 'the-pearl-hotel-new-york',
#    'name': 'The Pearl Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NuHw8TJ1IS8PymdutbtkHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pearl-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 135,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76146, 'longitude': -73.98548},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '233 W 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233 W 49th St', 'New York, NY 10019']},
#    'phone': '+12122454000',
#    'display_phone': '(212) 245-4000',
#    'distance': 607.3169348215278},
#   {'id': 'hfn7V_uEkn4wvjVrdyqq4A',
#    'alias': 'gardens-suite-hotel-by-affinia-new-york',
#    'name': 'Gardens Suite Hotel, by Affinia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/11HspC43TqMB24ZZR2MCFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gardens-suite-hotel-by-affinia-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 57,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76441, 'longitude': -73.96308},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '215 E 64th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 E 64th St', 'New York, NY 10065']},
#    'phone': '+12123551230',
#    'display_phone': '(212) 355-1230',
#    'distance': 1384.1667781333347},
#   {'id': 'NIpWK8ncyIz-ZhT_swINtQ',
#    'alias': 'the-artezen-hotel-new-york',
#    'name': 'The Artezen Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nJIJTwkotASRZqnslRUYtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-artezen-hotel-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 21,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.70964, 'longitude': -74.00869},
#    'transactions': [],
#    'location': {'address1': '24 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 John St', 'New York, NY 10038']},
#    'phone': '+12125665511',
#    'display_phone': '(212) 566-5511',
#    'distance': 6180.149603849538},
#   {'id': 'whVaI4qtx4Fseff5owxOaw',
#    'alias': 'hampton-inn-manhattan-times-square-central-new-york',
#    'name': 'Hampton Inn Manhattan/Times Square Central',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zKmx3D8zsyO4WX5gON4j6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampton-inn-manhattan-times-square-central-new-york?adjust_creative=UJ3sgzXTZYWFuWK3PG9-Qw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UJ3sgzXTZYWFuWK3PG9-Qw',
#    'review_count': 83,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7556070717413,
#     'longitude': -73.9886632561684},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '220 West 41st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['220 West 41st St', 'New York, NY 10036']},
#    'phone': '+12122211188',
#    'display_phone': '(212) 221-1188',
#    'distance': 997.6190561808341}],
#  'total': 1100,
#  'region': {'center': {'longitude': -73.97850036621094,
#    'latitude': 40.76021491079617}}}

# %% [markdown]
# ### Foriegn Keys
#
# For this project you will have two tables that you need to link using a foreign key. Below is some information about how to create a foriegn key.
#
# http://www.mysqltutorial.org/mysql-foreign-key/

# %% [markdown]
# ### Using DB:
#
# For this lab, you can either store the data on one DB or put in on both of the partners DBs. If you decide to put it on one DB, you want to make sure both partners have access to it.  To do this you want to add a user to your DB.
#
# [how to add a new user](https://howchoo.com/g/mtm3zdq2nzv/how-to-add-a-mysql-user-and-grant-privileges)

# %%
## Connect to DB server on AWS

# %%
## Create new DB

# %%
# Create a table for the Businesses

# %%
# Create a table for the reviews

# %% [markdown]
# ## Part 3 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %%
# Write a function to make a call to the yelp API

# %%
# write a function to parse the API response 
# so that you can easily insert the data in to the DB

# %%
# Write a function to take your parsed data and insert it into the DB

# %%
# Write a script that combines the three functions above into a single process.

# %% [markdown]
# ## Part 4 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews.

# %%
# write a SQL query to pull back all of the business ids 
# you will need these ids to pull back the reviews for each restaurant

# %%
# write a function that takes a business id 
# and makes a call to the API for reivews

# %%
# Write a function to parse out the relevant information from the reviews

# %%
# write a function to insert the parsed data into the reviews table

# %%
# combine the functions above into a single script

# %% [markdown]
# ## Part 5 -  Write SQL queries that will answer the questions posed.
#
# Now that your data is in the DB, you can answer the questions. Write SQL querires that will answer the questions. **Do not use Pandas in this lab**

# %%
# create connection

# %%
# execute SQL queries

# %% [markdown]
# # Extra Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
def yelp_biz_call(term = "Hotel", location = 'Manhattan', limit = 50, offset = None):
    api_key = "6bStfv8q6DhKbrjmsGYuadW142rYO82aNOJIKBftA9q3ITEu_eCtvjUm-N6UmafgY_mP-SD-cOaw__llL6pt4Bp3QCGMkvy8aeUg--SYE1WIfTB_gk4TkPaHKvcpXnYx"

    url = 'https://api.yelp.com/v3/businesses/search'

    headers = {
            'Authorization': 'Bearer {}'.format(api_key),
        }

    url_params = {
                    'term': term.replace(' ', '+'),
                    'location': location.replace(' ', '+'),
                    'limit': limit
                }
    response = requests.get(url, headers=headers, params=url_params)
    return response

# %%
yelp_biz_call("Hotel", "Manhattan", 50, None)
# Out:
# <Response [200]>

# %%
def parse_results(results):
    # your code to parse the result to make them easier to insert into the DB
    return parsed_results

# %%
def db_insert(cnx, cursor, parsed results):
    # your code to insert and commit the results
    # I would create the connection and cursor outside of this function and then pass it through

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50
